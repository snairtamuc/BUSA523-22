# %%
import pandas as pd

data = pd.read_csv("data.csv")

data
# Out:
#            Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0        5/2/10        42.31       2.572        NaN        NaN        NaN
# 1       12/2/10        38.51       2.548        NaN        NaN        NaN
# 2    19/02/2010        39.93       2.514        NaN        NaN        NaN
# 3    26/02/2010        46.63       2.561        NaN        NaN        NaN
# 4        5/3/10        46.50       2.625        NaN        NaN        NaN
# ..          ...          ...         ...        ...        ...        ...
# 138  28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 139     5/10/12        68.55       3.617    8077.89        NaN      18.22
# 140    12/10/12        62.99       3.601    2086.18        NaN       8.11
# 141  19/10/2012        67.97       3.594     950.33        NaN       4.93
# 142  26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#      MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
records = pd.read_csv("data.csv", header = 0, index_col = 0)
records
# Out:
#             Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 5/2/10            42.31       2.572        NaN        NaN        NaN
# 12/2/10           38.51       2.548        NaN        NaN        NaN
# 19/02/2010        39.93       2.514        NaN        NaN        NaN
# 26/02/2010        46.63       2.561        NaN        NaN        NaN
# 5/3/10            46.50       2.625        NaN        NaN        NaN
# ...                 ...         ...        ...        ...        ...
# 28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 5/10/12           68.55       3.617    8077.89        NaN      18.22
# 12/10/12          62.99       3.601    2086.18        NaN       8.11
# 19/10/2012        67.97       3.594     950.33        NaN       4.93
# 26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#             MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# Date
# ...

# %%
records['dept_1 sales'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
records['Temperature'].plot.hist()
plt.xlabel('Temperature')
plt.title('Temperature Distribution')
# Out:
# Text(0.5, 1.0, 'Temperature Distribution')

# %%
plt.hist(records["Fuel_Price"])
plt.xlabel('Fuel_Price')
# Out:
# Text(0.5, 0, 'Fuel_Price')

# %%
records.CPI.plot.hist();
plt.xlabel('CPI')
# Out:
# Text(0.5, 0, 'CPI')

# %%
records.plot.scatter(x="CPI", y="Fuel_Price")
# Out:
# <AxesSubplot:xlabel='CPI', ylabel='Fuel_Price'>

# %%
records.plot.scatter(x="Temperature", y="Fuel_Price")
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Fuel_Price'>

# %%
import matplotlib.pyplot as plt
#fig, ax = plt.subplots()

#ax.plot(records['Temperature'], records['Fuel_Price'])
#ax.plot(records['Temperature'], records['Unemployment'])

records.plot.line(y='CPI')
records.plot.line(y='Fuel_Price')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.pyplot as plt
import pandas as pd

records = pd.read_csv("data.csv", header = 0, index_col = 0)
records
# Out:
#             Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 5/2/10            42.31       2.572        NaN        NaN        NaN
# 12/2/10           38.51       2.548        NaN        NaN        NaN
# 19/02/2010        39.93       2.514        NaN        NaN        NaN
# 26/02/2010        46.63       2.561        NaN        NaN        NaN
# 5/3/10            46.50       2.625        NaN        NaN        NaN
# ...                 ...         ...        ...        ...        ...
# 28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 5/10/12           68.55       3.617    8077.89        NaN      18.22
# 12/10/12          62.99       3.601    2086.18        NaN       8.11
# 19/10/2012        67.97       3.594     950.33        NaN       4.93
# 26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#             MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# Date
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(records['CPI'], records['dept_3 sales'])
ax.plot(records['CPI'], records['dept_2 sales'])
ax.plot(records['CPI'], records['dept_1 sales'])
plt.show()

# %%
import pandas as pd

data = pd.read_csv("data.csv")

data

import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(data['Date'], data['Temperature'])

plt.show()

# %%
fig, ax = plt.subplots()

ax.pie([data['dept_1 sales'].sum(), data['dept_2 sales'].sum(), data['dept_3 sales'].sum()], labels=['dept_1 sales', 'dept_2 sales','dept_3 sales'])

ax.set_title('Sales by department')

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(data['Day type'], data['dept_3 sales'])
ax.plot(data['Day type'], data['dept_2 sales'])
ax.plot(data['Day type'], data['dept_1 sales'])
plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(data['Day type'],data['dept_1 sales'])


ax.set_title('Sales by Day type for Department 1')

plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(data['Day type'],data['dept_2 sales'])
ax.set_title('Sales by Day type for Department 2')
# Out:
# Text(0.5, 1.0, 'Sales by Day type for Department 2')

# %%
fig, ax = plt.subplots()
ax.bar(data['Day type'],data['dept_3 sales'])
ax.set_title('Sales by Day type for Department 3')
# Out:
# Text(0.5, 1.0, 'Sales by Day type for Department 3')

# %%
plt.bar(x=data['Day type'], height = data['MarkDown1'], label='MD1')
plt.bar(x=data['Day type'], height = data['MarkDown2'], label='MD2')
plt.bar(x=data['Day type'], height = data['MarkDown3'], label='MD3')
plt.bar(x=data['Day type'], height = data['MarkDown4'], label='MD4')
plt.bar(x=data['Day type'], height = data['MarkDown5'], label='MD5')
plt.title('Markdowns based on Day type')
plt.xlabel('Day type')
plt.ylabel('Markdown')
plt.legend(loc='upper left')

# %%
data.plot.area('CPI','dept_3 sales')
data.plot.area('CPI','dept_2 sales')

data.plot.area('CPI','dept_1 sales')
# Out:
# <AxesSubplot:xlabel='CPI'>

# %%
data.plot.area()
# Out:
# <AxesSubplot:>
