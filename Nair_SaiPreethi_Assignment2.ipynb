# %%
#Question 1


import random
import string

List = []

def flipCoin():
    return random.choice(['Heads','Tails'])

for i in range(0,10000):
    List.append(flipCoin())
    
    
print(List)

    
#List_Outcome = [flipCoin]  
#print (List_Outcome)
# Out:
# ['Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Heads', 'Tails', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails'
# ...

# %%
#Question 2

import random
Inventory = {}
Swords =  int(input("Enter Number of Swords: "))
Diamonds = int(input("Enter the Diamonds: "))
GoldCoins = int(input("Enter the Gold Coins: "))
Ropes = int(input("Enter the ropes: "))
Potions  = int(input("Enter the Potions: "))

Data = {5 : 'Swords', 
       10 : 'Diamonds' ,
        6 : 'GoldCoins', 
       3 : 'Ropes', 
       2 : 'Potions'}
Inventory = Data
print ("Inventory")
print(Inventory)
# Out:
# Enter Number of Swords: 5
# Enter the Diamonds: 10
# Enter the Gold Coins: 6
# Enter the ropes: 3
# Enter the Potions: 2
# Inventory
# {5: 'Swords', 10: 'Diamonds', 6: 'GoldCoins', 3: 'Ropes', 2: 'Potions'}

# %%
#Question3

import numpy as np



np.random.randint(0,2)

n = 10000

x = np.random.randint(0, 2, size = n)
x
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
#Question 4

import random

def diceRoll():
    number = random.randint(1, 6)
    return number

player1 = 0
player2 = 0
player3 = 0
rounds = 0
player1Score = 0
player2Score = 0
player3Score = 0
   
while rounds != 10:
    rounds += 1
    print(rounds)
    player1 = diceRoll()
    print(f"player 1 =  {player1}")

    player2 = diceRoll()
    print(f"player 2 =  {player2}")

    player3 = diceRoll()
    print(f"player 3 =  {player3}")
   
    if(player1 == player2 and player2 == player3):
        player1Score += 1
        player2Score += 1
        player3score += 1
        continue
    
    if(player1 == player2):      
        if(player1 > player3):
            player1Score += 1
            player2Score += 1
            print(f"player 1 score =  {player1Score}")
            print(f"player 2 score =  {player2Score}")
            continue

        else:
            player3Score += 1
            print(f"player 3 score =  {player3Score}")
            continue
   
    if(player1 == player3):      
        if(player1 > player2):
            player1Score += 1
            player3Score += 1
            print(f"player 1 score =  {player1Score}")
            print(f"player 3 score =  {player3Score}")
            continue
       
        else:
            player2Score += 1
            print(f"player 2 score =  {player2Score}")
            continue
       
    if(player2 == player3):      
        if(player2 > player1):
            player2Score += 1
            player3Score += 1
            print(f"player 2 score =  {player2Score}")
            print(f"player 3 score =  {player3Score}")
            continue
           
        else:
            player1Score += 1
            print(f"player 1 score =  {player1Score}")
            continue
           
    if(player1 > player2):
            if(player1 > player3):
                player1Score += 1
                print(f"player 1 score =  {player1Score}")
                continue
           
            else:
                player3Score += 1
                print(f"player 3 score =  {player3Score}")
                continue
           
    if(player2 > player1):
        if(player2 > player3):
            player2Score += 1
            print(f"player 2 score =  {player2Score}")
            continue
       
        else:
            player3Score += 1
            print(f"player 3 score =  {player3Score}")
            continue
   
if(player1Score > player2Score):
    if(player1Score > player2Score):
        print("Winner is Player 1!")
    else:
        print("Winner is Player 3!")
               
if(player2Score > player1Score):
    if(player2Score > player3Score):
        print("Winner is Player 2!")
    else:
        print("Winner is Player 3!")
# Out:
# 1
# player 1 =  3
# player 2 =  3
# player 3 =  2
# player 1 score =  1
# player 2 score =  1
# 2
# player 1 =  5
# player 2 =  1
# player 3 =  3
# player 1 score =  2
# 3
# player 1 =  4
# player 2 =  3
# player 3 =  2
# player 1 score =  3
# 4
# player 1 =  1
# player 2 =  3
# player 3 =  5
# player 3 score =  1
# 5
# player 1 =  1
# player 2 =  4
# player 3 =  4
# player 2 score =  2
# player 3 score =  2
# 6
# player 1 =  5
# player 2 =  5
# player 3 =  4
# player 1 score =  4
# player 2 score =  3
# 7
# player 1 =  2
# player 2 =  6
# player 3 =  4
# player 2 score =  4
# 8
# player 1 =  2
# player 2 =  5
# player 3 =  4
# player 2 score =  5
# 9
# player 1 =  2
# player 2 =  1
# player 3 =  3
# player 3 score =  3
# 10
# player 1 =  1
# player 2 =  2
# player 3 =  6
# player 3 score =  4
# Winner is Player 2!
